# %%
import pandas as pd
import numpy as np

# %%
state_data = pd.read_csv("state_longterm_care_list.csv")
state_data.head()
# Out:
#      ID                                   Provider Name
# 0  1857    Libby of Cascadia, LLC dba Libby Care Center  \
# 1  1053  Aspen Meadows Health and Rehabilitation Center
# 2  1289                            AVANTARA OF BILLINGS
# 3   812                     Awe Kualawaache Care Center
# 4  1163                         Bella Terra of Billings
#
#                  Address         City    Zip    License Type  License #
# 0  308 East Third Street        LIBBY  59923  Long Term Care      13566  \
# 1          3155 Avenue C     Billings  59102  Long Term Care      13565
# 2       2115 Central Ave     BILLINGS  59102  Long Term Care      13569
# 3    10131 S Heritage Rd  Crow Agency  59022  Long Term Care      12935
# 4     1807 24th Street W     Billings  59102  Long Term Care      13570
#
#   State Inspection Recorded Inspection Date  Inspection Date.1
# 0                         N             NaN                NaN  \
# 1                         N             NaN                NaN
# ...

# %%
federal_data = pd.read_csv("federal_nursing_home_cms.csv")
federal_data.head()
# Out:
#                                 state list copied federal_provider_number
# 0  Aspen Meadows Health and Rehabilitation Center                  275140  \
# 1                            AVANTARA OF BILLINGS                  275029
# 2                     Awe Kualawaache Care Center                  275153
# 3                                             NaN                  275090
# 4                         Bella Terra of Billings                  275020
#
#                                     provider_name     provider_address
# 0  ASPEN MEADOWS HEALTH AND REHABILITATION CENTER           3155 AVE C  \
# 1                            AVANTARA OF BILLINGS     2115 CENTRAL AVE
# 2                     AWE KUALAWAACHE CARE CENTER  10131 S HERITAGE RD
# 3                                 BEARTOOTH MANOR       350 W PIKE AVE
# 4                         BELLA TERRA OF BILLINGS       1807 24TH ST W
#
#   provider_city provider_state  provider_zip_code  provider_phone_number
# ...
